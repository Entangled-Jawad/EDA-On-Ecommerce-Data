# %% [markdown]
# # **Ecommerce Data set**
# **Complete Exploratory Data Analysis**

# %% [markdown]
# ## About Dataset
#
# >- **`Description`**\
# > The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/zusmani/pakistans-largest-ecommerce-dataset/data)
#
#
# - `Context`
#
#   This is the largest retail e-commerce orders dataset from Pakistan. It contains half a million transaction records from March 2016 to August 2018. The data was collected from various e-commerce merchants as part of a research study. I am releasing this dataset as a capstone project for my data science course at Alnafi (alnafi.com/zusmani).
# There is a dire need for such dataset to learn about Pakistan’s emerging e-commerce potential and I hope this will help many startups in many ways.
#
# - `Content`
#
#   Geography: Pakistan
#
# Time period: 03/2016 – 08/2018
#
# Unit of analysis: E-Commerce Order
#
# - `Acknowledgements`
#
#   I like to thank all the startups who are trying to make their mark in Pakistan despite the unavailability of research data.
#
# - `Inspiration`
#
# I’d like to call the attention of my fellow Kagglers to use Machine Learning and Data Sciences to help me explore these ideas:
#
# • What is the best-selling category?
# • Visualize payment method and order status frequency
# • Find a correlation between payment method and order status
# • Find a correlation between order date and item category
# • Find any hidden patterns that are counter-intuitive for a layman
# • Can we predict number of orders, or item category or number of customers/amount in advance?

# %% [markdown]
#  # ***`Insights`***
#  So following are the insights that i fetch from this data usind Eexploratory Data Analysis
#  1. In the year 2018 maximum quantity is ordered
#  2. Mobile and Tablets are ordered or sold maximum
#  3. In November(11.0) we got highest orders and in September(9.0) we have least orders
#  4. most of the  customers are comforatble with COD payment method
#  5. Customers got highest Discount on the Entertainment items
#  6. Customers got highest Discount on the Entertainment items

# %% [markdown]
# ## 1. ***Importing Libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
# hide all warnings runtime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. **Data Loading, Exploration, and Cleansing**
#
#  ↪ Load the CSV file into a Pandas DataFrame
#
#  ↪ Investigate and comprehend the data within the dataset using Pandas
#
#  ↪ Address the following data quality concerns:
#
# - Handle missing data
# - Identify and manage outliers
# - Rectify any incorrect or invalid records

# %%
df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")

# %% [markdown]
# - Lets have a look on fist 5 some columns and rows

# %%
df.head(5)
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  \
# 0       1950.0    100147443    Women's Fashion                    \N
# 1        240.0    100147444  Beauty & Grooming                    \N
# 2       2450.0    100147445    Women's Fashion                    \N
# ...

# %% [markdown]
# > ***Note*** In order to show the complete output of the rows and columns. We used these commands

# %%
pd.set_option('display.max_columns', None, 'display.max_rows', None)

# %%
df.head(5)
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  \
# 0       1950.0    100147443    Women's Fashion                    \N
# 1        240.0    100147444  Beauty & Grooming                    \N
# 2       2450.0    100147445    Women's Fashion                    \N
# ...

# %% [markdown]
# - Lets have a look on the names of the columns in the dataset

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %% [markdown]
# - Lets check out datatypes, no of columns, rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %% [markdown]
#  **Observations**
#
# - No of Columns = 26
# - No of Rows    = 1048575
# - So here in the data set some of the columns are unnamed and they are not much important so we can drop these columns.

# %% [markdown]
#  Dropping the `Unnamed` columns

# %%
# Identify the unnamed columns
column_names = df.columns
unnamed_columns = [col for col in column_names if 'Unnamed' in col]
# Drop the unnamed columns
df = df.drop(unnamed_columns, axis=1)

# Save the updated dataset
df.to_csv('updated_dataset.csv', index=False)

# %% [markdown]
# Lets check whether they are dropped or not

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %% [markdown]
# `Note` Here are some full forms of the columns
# - sku = stock Keeping Unit
# - MV  = Market Value
# - M-Y = Month-Year
# - FY  = Fiscal Year

# %% [markdown]
# Lets have a check on the data types

# %%
df.dtypes
# Out:
# item_id                  float64
# status                    object
# created_at                object
# sku                       object
# price                    float64
# qty_ordered              float64
# grand_total              float64
# increment_id              object
# category_name_1           object
# sales_commission_code     object
# discount_amount          float64
# payment_method            object
# Working Date              object
# BI Status                 object
#  MV                       object
# Year                     float64
# Month                    float64
# Customer Since            object
# M-Y                       object
# FY                        object
# Customer ID              float64
# dtype: object

# %% [markdown]
# # 3. Checking Null Values And Duplicates

# %%
df.isnull().sum()
# Out:
# item_id                  464051
# status                   464066
# created_at               464051
# sku                      464071
# price                    464051
# qty_ordered              464051
# grand_total              464051
# increment_id             464051
# category_name_1          464215
# sales_commission_code    601229
# discount_amount          464051
# payment_method           464051
# Working Date             464051
# BI Status                464051
#  MV                      464051
# Year                     464051
# Month                    464051
# Customer Since           464062
# M-Y                      464051
# FY                       464051
# Customer ID              464062
# dtype: int64

# %% [markdown]
# - Checking duplicates first

# %%
df.duplicated().sum()
# Out:
# np.int64(464050)

# %% [markdown]
# - A lot of `Duplicates` lets remove them

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - Now lets check `Null values`

# %%
df.isnull().sum()
# Out:
# item_id                       1
# status                       16
# created_at                    1
# sku                          21
# price                         1
# qty_ordered                   1
# grand_total                   1
# increment_id                  1
# category_name_1             165
# sales_commission_code    137179
# discount_amount               1
# payment_method                1
# Working Date                  1
# BI Status                     1
#  MV                           1
# Year                          1
# Month                         1
# Customer Since               12
# M-Y                           1
# FY                            1
# Customer ID                  12
# dtype: int64

# %%
((df.isnull().sum() / len(df) * 100) ).sort_values(ascending = False)
# Out:
# sales_commission_code    23.468457
# category_name_1           0.028228
# sku                       0.003593
# status                    0.002737
# Customer Since            0.002053
# Customer ID               0.002053
# price                     0.000171
# item_id                   0.000171
# created_at                0.000171
# increment_id              0.000171
# discount_amount           0.000171
# grand_total               0.000171
# qty_ordered               0.000171
# Working Date              0.000171
# payment_method            0.000171
# BI Status                 0.000171
#  MV                       0.000171
# Month                     0.000171
# Year                      0.000171
# M-Y                       0.000171
# FY                        0.000171
# dtype: float64

# %% [markdown]
# - So `sales_commission_code` column have highest null values and this column is not important as well and the reason is that this column have no corelation with any other column so lets drop it

# %%
df = df.drop('sales_commission_code', axis=1)

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1', 'discount_amount',
#        'payment_method', 'Working Date', 'BI Status', ' MV ', 'Year', 'Month',
#        'Customer Since', 'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# category_name_1    165
# sku                 21
# status              16
# Customer ID         12
# Customer Since      12
# item_id              1
# created_at           1
# price                1
# increment_id         1
# discount_amount      1
# grand_total          1
# qty_ordered          1
# Working Date         1
# payment_method       1
# BI Status            1
#  MV                  1
# Month                1
# Year                 1
# M-Y                  1
# FY                   1
# dtype: int64

# %% [markdown]
# - `Note` Usually we use mean mode and median method for the missing values but here there is no need to do that because the missing values are in low perscent

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# item_id            0
# status             0
# created_at         0
# sku                0
# price              0
# qty_ordered        0
# grand_total        0
# increment_id       0
# category_name_1    0
# discount_amount    0
# payment_method     0
# Working Date       0
# BI Status          0
#  MV                0
# Year               0
# Month              0
# Customer Since     0
# M-Y                0
# FY                 0
# Customer ID        0
# dtype: int64

# %% [markdown]
# # 4. *Plotting*

# %% [markdown]
# ## 4.1 Quantity ordered per year

# %%
# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.barplot(y='qty_ordered', x='Year', data=df)
plt.title('qty_ordered vs Year')
plt.xlabel('year')
plt.ylabel('qty_ordered')
plt.show()

# %% [markdown]
# `Insight` so in year 2018 maximum quantity is ordered

# %% [markdown]
# ## 4.2 *Total Quantity Ordered per Category*

# %%
# Calculate the total quantity ordered per category
total_qty_per_category = df.groupby('category_name_1')['qty_ordered'].sum().sort_values(ascending=False)

# Find the category with the maximum total quantity ordered
max_category = total_qty_per_category.index[0]
max_qty = total_qty_per_category.iloc[0]

# Create the bar plot
plt.figure(figsize=(8, 6))
total_qty_per_category.plot(kind='bar')
plt.title(f'Total Quantity Ordered per Category\nMax: {max_category} ({max_qty:.0f})')
plt.xlabel('category_name_1')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `Mobile and Tablets are ordered or sold maximum`

# %% [markdown]
# # 4.3 *Order Distribution by Month*

# %%
# Assuming your DataFrame is called 'df'
monthly_counts = df.groupby(df['Month'])['item_id'].count()

# Plot pie chart
plt.figure(figsize=(6, 6))  # Adjust the figure size as needed
plt.pie(monthly_counts, labels=monthly_counts.index, autopct='%1.1f%%')

# Add title and labels
plt.title('Orders by Month')
plt.axis('equal')  # Ensure the pie chart is circular
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# `So In November(11.0) we got highest orders and in September(9.0) we have least orders`

# %% [markdown]
# # 4.4 *Distribution of Order Statuses*

# %%
# Calculate the count of orders for each status
order_status_count = df['status'].value_counts().sort_values(ascending= False).head(5)

# Create the pie chart
plt.figure(figsize=(6, 6))
order_status_count.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Order Statuses')
plt.axis('equal')
plt.legend(title='Order Status', labels=order_status_count.index)
plt.show()

# %% [markdown]
# # 4.5 *Orders by Payment Method*

# %%
# Count the number of orders for each payment method
payment_method_counts = df['payment_method'].value_counts()

# Create the bar plot
plt.figure(figsize=(12, 6))
payment_method_counts.plot(kind='bar')
plt.title('Orders by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('qty_ordered')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `SO most of the  customers are comforatble with COD payment method`

# %% [markdown]
# # 4.6 *Highest Discount by Category*

# %%
 #Find the maximum discount for each category
max_discount_by_category = df.groupby('category_name_1')['discount_amount'].max()

# Create the bar plot
plt.figure(figsize=(12, 6))
max_discount_by_category.plot(kind='bar')
plt.title('Highest Discount by Category')
plt.xlabel('category_name_1')
plt.ylabel('Highest Discount')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `Customers got highest Discount on the Entertainment items `

# %% [markdown]
# # 4.7 *Customer Acquisition Trend*

# %%
plt.figure(figsize= ( 16 , 6))
df['Customer Since'] = pd.to_datetime(df['Customer Since'])
customer_acquisition = df['Customer Since'].value_counts().sort_index()
customer_acquisition.plot()
plt.title('Customer Acquisition Trend')
plt.xlabel('Date')
plt.ylabel('New Customers')
plt.show()
